# %% [markdown]
# *As of Project PyTHAGORA Alpha Release 7/24/2024, this project/lesson is known to be incomplete, early updates should include the creation and testing of this lesson.*
#
# *Updated 8/14/2024*

# %% [markdown]
# # Set Up

# %% [markdown]
# This first project is to give you an understanding of how benchmark projects like this will be formatted. Overall there will be a set-up tab which includes imports and general housekeeping before you can begin coding. Then there will be several smaller parts of increasing difficulty which will be used to test your understanding of associated material as well as related coding skills.
#
# In this first project I will walk you through many of the solutions and how to complete the parts but as you progress through the course I will provide less and less help.
#
# Let's get started

# %%
import math

# %% [markdown]
# # Introduction Project

# %% [markdown]
# Because we have only covered one lesson on Python, this project will rely almost solely on your math skills. In the same spirit as later projects the questions will start easy and get more difficult.

# %% [markdown]
# #### **(P1)**
#
# Consider the error message produced from running the following code, then re-write the cell to fix the error.
# ```
# >>>print(hello world)
# Cell In[2],   line 1
#     print(hello world)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
# ```

# %% [markdown]
# #### **(P2)**
#
# Lets do some more work with strings. Use the code block below to get started. Fill in the first and last name variables with whatever you would like, add the strings together, and print the output.
#
# ```
# greeting = "Hello, my name is"
# first_name =
# last_name =
# ```

# %% [markdown]
# #### **(P3)**
#
# The math module provides useful functions as well as constant values such as pi. Lets use those. Write a script to find the cirumference of one end, the surface area, and volume of any cylinder using the radius and height. Then print these values. For the value of pi, you will need to use `math.pi`
#
# *Hint: circumference is $2\times\pi\times r$, volume is $2\times\pi\times h\times r^2$, surface area is $2\times\pi\times r^2 + 2\times\pi\times r\times h$*
#
# *The instructor solution uses r = 1 and h = 5 if you would like to compare your results, units are not necessarily important though we will revisit this problem in [3-6 Astropy](../Module3_DataTasks/3-6%20Astropy%20Lesson.ipynb) to test the `astropy.units` functionality.*

# %% [markdown]
# #### **(P4)**
#
# Given the equations $y = 7x$ and $x = \sqrt{y}$, find the points that the two lines intersect. This problem will be primarily algebra and less programming, but in remember what steps you take because in [3-3 Sympy](../Module3_DataTasks/3-3%20Sympy%20Lesson.ipynb) we will cover how to do symbolic algebra with Python and the package Sympy by revisiting this problem.

# %% [markdown]
# **(P4.1)** Solve each equation for y in terms of x (one is already done for you).

# %% [markdown]
# **(P4.2)** Set the two equations equal to each other and solve for x.

# %% [markdown]
# **(P4.3)** Find the solutions to the quadratic equation and their corresponding y-values.
# *Hint: the standard form of a quadratic equation can be written $ax^2 +bx +c = 0$*
# *Hint: the math module has a square root function*

# %% [markdown]
# # End

# %% [markdown]
# As of the most recent update to Project PyTHAGORA, you have completed the zeroeth mini-project. Hopefully this has given you an idea of how future projects will be structured and what to expect from them. Keep in mind that these problems were fairly simple, as the lessons go on, the problems will get harder.

# %% [markdown]
# In the future we hope to incorperate some form of automatic grading, but for now you can compare your results with the [instructor version](../Project%20Solutions/1a-2%20Project%200-1%20First%20Project_MASTER.ipynb) and move on to [1b-1 Lists](./1b-1%20Lists.ipynb).
